# %%
import csv

with open('PLL_Player_Gamelogs_Raw.csv') as f:
    data = [{k: str(v) for k, v in row.items()}
        for row in csv.DictReader(f, skipinitialspace=True)]

# %% [raw]
# Assumptions:
#     no players with same name, names are unique
#     players played for one team the whole season
#     Seasons 2019, 2020, 2021 - tell what season by EventId
#     Goals - includes 1 and 2 point goals, 1 and 2 point goals count as 1 goal in this column
#     Shots, ShotPct,ShotsOnGoal,ShotsOnGoalsPct includes all shots
#     TwoPointGoals, TwoPointShots, TwoPointShotsPct, TwoPointShotsOnGoal, TwoPointShotsOnGoalPct - only counts two     point shot attempts

# %%
import pandas as pd

df = pd.read_csv("PLL_Player_Gamelogs_Raw.csv")
df2 = df[['Player','Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct','position','year','SeasonSegment']].copy()
df2 = df2[df2['position'].isin(['A','M'])]
df2 = df2[df2['SeasonSegment'].isin(['SeasonSegmentRegseason'])]
df_2019 = df2[df2['year'].isin([2019])]
df_2020 = df2[df2['year'].isin([2020])]
df_2021 = df2[df2['year'].isin([2021])]

# %%
import tabulate 
by_player_2019 = df_2019.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2019
by_player_2019 = by_player_2019.loc[by_player_2019['Shots'] > 0]
by_player_2019
# Out:
#             Player  Goals  Shots   ShotPct  ShotsOnGoal  ShotsOnGoalPct
# 0   Andrew Hodgson      0      2  0.000000            0        0.000000
# 1      Austin Sims      2     12  0.166667            6        0.250000
# 2     Ben McIntosh     11     45  0.238095           27        0.358333
# 3       Ben Reeves      6     25  0.160417           17        0.229167
# 4      Brent Adams     10     36  0.266667           21        0.408333
# ..             ...    ...    ...       ...          ...             ...
# 73     Ty Thompson      2      5  0.250000            4        0.250000
# 74   Tyler Pfister      0      5  0.000000            2        0.000000
# 75    Tyler Warner      1      4  0.100000            1        0.100000
# 76        Wes Berg      4      8  0.500000            7        0.541667
# 77      Will Manny     22     72  0.306439           50        0.446667
#
# [74 rows x 6 columns]

# %%
by_player_2020 = df_2020.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2020
by_player_2020 = by_player_2020.loc[by_player_2020['Shots'] > 0]
by_player_2020
# Out:
#              Player  Goals  Shots   ShotPct  ShotsOnGoal  ShotsOnGoalPct
# 0     Austin Staats      5     12  0.500000           10        0.500000
# 1      Ben McIntosh      6     21  0.286667           16        0.383333
# 2        Ben Reeves      0      9  0.000000            6        0.000000
# 3        Brad Smith      8     29  0.280754           20        0.402778
# 4   Brendan Gleason      3     10  0.305556            4        0.416667
# ..              ...    ...    ...       ...          ...             ...
# 67     Tyler Warner      0      2  0.000000            1        0.000000
# 68         Wes Berg      1     12  0.040000            9        0.050000
# 69       Will Manny     10     39  0.257143           28        0.365873
# 70     Zach Currier      4      8  0.375000            5        0.500000
# 71     Zed Williams     20     59  0.316757           37        0.516667
#
# [69 rows x 6 columns]

# %%
by_player_2021 = df_2021.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2021
by_player_2021 = by_player_2021.loc[by_player_2021['Shots'] > 0]
by_player_2021
# Out:
#            Player  Goals  Shots   ShotPct  ShotsOnGoal  ShotsOnGoalPct
# 0      Andrew Kew     10     23  0.368056           17        0.430556
# 1   Austin Staats      0      1  0.000000            1        0.000000
# 2    Ben McIntosh      3     11  0.300000            8        0.312500
# 3      Ben Reeves      8     23  0.260417           15        0.312500
# 4      Brad Smith     11     47  0.223810           25        0.540741
# ..            ...    ...    ...       ...          ...             ...
# 91   Tre Leclaire      7     16  0.416667            9        0.666667
# 92       Wes Berg      5     11  0.350000            7        0.550000
# 93     Will Manny     19     50  0.354762           37        0.478704
# 95   Zach Currier     11     40  0.303704           24        0.525926
# 96   Zed Williams     23     79  0.272810           51        0.403472
#
# [92 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize = (7.5, 5))
 
plt.scatter(by_player_2019['Goals'], by_player_2019['Shots'],color = 'blue')
plt.scatter(by_player_2020['Goals'], by_player_2020['Shots'],color = 'red')
plt.scatter(by_player_2021['Goals'], by_player_2021['Shots'], color = 'green')
plt.xticks()
plt.xlabel("Goals")
plt.ylabel("Shots")
plt.title("Goals vs Shots")
plt.legend(["2019","2020","2021"])
#plt.show()
plt.savefig('img/player_goals_vs_shots.png')

# %%
fig = plt.figure(figsize = (7.5, 5))

plt.scatter(by_player_2019['Goals'], by_player_2019['ShotPct'],color = 'blue')
plt.scatter(by_player_2020['Goals'], by_player_2020['ShotPct'],color = 'red')
plt.scatter(by_player_2021['Goals'], by_player_2021['ShotPct'], color = 'green')
plt.xticks()
plt.xlabel("Goals")
plt.ylabel("ShotPct")
plt.title("Goals vs ShotPct")
plt.legend(["2019","2020","2021"])
#plt.show()
plt.savefig('img/player_goals_vs_shotpct.png')

# %%
fig = plt.figure(figsize = (7.5, 5))

plt.scatter(by_player_2019['Goals'], by_player_2019['ShotsOnGoal'],color = 'blue')
plt.scatter(by_player_2020['Goals'], by_player_2020['ShotsOnGoal'],color = 'red')
plt.scatter(by_player_2021['Goals'], by_player_2021['ShotsOnGoal'], color = 'green')
plt.xticks()
plt.xlabel("Goals")
plt.ylabel("ShotsOnGoal")
plt.title("Goals vs ShotsOnGoal")
plt.legend(["2019","2020","2021"])
#plt.show()
plt.savefig('img/player_goals_vs_shotsongoal.png')

# %%
fig = plt.figure(figsize = (7.5, 5))

plt.scatter(by_player_2019['Goals'], by_player_2019['ShotsOnGoalPct'],color = 'blue')
plt.scatter(by_player_2020['Goals'], by_player_2020['ShotsOnGoalPct'],color = 'red')
plt.scatter(by_player_2021['Goals'], by_player_2021['ShotsOnGoalPct'], color = 'green')
plt.xticks()
plt.xlabel("Goals")
plt.ylabel("ShotsOnGoalPct")
plt.title("Goals vs ShotsOnGoalPct")
plt.legend(["2019","2020","2021"])
#plt.show()
plt.savefig('img/player_goals_vs_shotsongoalpct.png')

# %%
by_player_2021_top10_goals = by_player_2021.nlargest(10,'Goals') 
#by_player_2021_top10_goals
by_player_2020_top10_goals = by_player_2020.nlargest(10,'Goals') 
#by_player_2020_top10_goals
by_player_2019_top10_goals = by_player_2019.nlargest(10,'Goals') 
by_player_2019_top10_goals
# Out:
#               Player  Goals  Shots   ShotPct  ShotsOnGoal  ShotsOnGoalPct
# 49     Marcus Holman     23     76  0.368773           43        0.565476
# 10     Connor Fields     22     61  0.387500           49        0.461667
# 77        Will Manny     22     72  0.306439           50        0.446667
# 40  Jules Heningburg     21     54  0.311667           33        0.513810
# 64        Ryan Brown     21     81  0.278327           49        0.446190
# 18          Eric Law     20     36  0.642500           32        0.705000
# 36  Jordan MacIntosh     20     47  0.395062           37        0.517284
# 41  Justin Guterding     19     60  0.339127           37        0.555000
# 52        Matt Rambo     19     66  0.300404           33        0.548810
# 66      Ryan Drenner     19     65  0.303301           40        0.514762

# %%
by_player_2021_avg = by_player_2021[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2021_avg
by_player_2020_avg = by_player_2020[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2020_avg
by_player_2019_avg = by_player_2019[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2019_avg
by_player_2021_75 = by_player_2021[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.75)
#by_player_2021_75
by_player_2020_75 = by_player_2020[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.75)
#by_player_2020_75
by_player_2019_75 = by_player_2019[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.75)
#by_player_2019_75
by_player_2021_25 = by_player_2021[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.25)
#by_player_2021_25
by_player_2020_25 = by_player_2020[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.25)
#by_player_2020_25
by_player_2019_25 = by_player_2019[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].quantile(.25)
by_player_2019_25
# Out:
# Goals             2.250000
# Shots             8.000000
# ShotPct           0.139583
# ShotsOnGoal       5.250000
# ShotsOnGoalPct    0.200926
# Name: 0.25, dtype: float64

# %%
fig = plt.figure(figsize = (5, 6))

plt.bar(by_player_2021_top10_goals['Player'],by_player_2021_top10_goals['Shots'])
plt.axhline(by_player_2021_avg['Shots'],color='red')
plt.axhline(by_player_2021_75['Shots'],color='orange')
plt.axhline(by_player_2021_25['Shots'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("Shots")
plt.title("Top 10 Goal Scorers Shots 2021")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shots2021.png')

# %%
fig = plt.figure(figsize = (5, 6))

plt.bar(by_player_2020_top10_goals['Player'],by_player_2020_top10_goals['Shots'])
plt.axhline(by_player_2020_avg['Shots'],color='red')
plt.axhline(by_player_2020_75['Shots'],color='orange')
plt.axhline(by_player_2020_25['Shots'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("Shots")
plt.title("Top 10 Goal Scorers Shots 2020")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shots2020.png')

# %%
fig = plt.figure(figsize = (5, 6))

plt.bar(by_player_2019_top10_goals['Player'],by_player_2019_top10_goals['Shots'])
plt.axhline(by_player_2019_avg['Shots'],color='red')
plt.axhline(by_player_2019_75['Shots'],color='orange')
plt.axhline(by_player_2019_25['Shots'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("Shots")
plt.title("Top 10 Goal Scorers Shots 2019")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shots2019.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2021_top10_goals['Player'],by_player_2021_top10_goals['ShotPct'])
plt.axhline(by_player_2021_avg['ShotPct'],color='red')
plt.axhline(by_player_2021_75['ShotPct'],color='orange')
plt.axhline(by_player_2021_25['ShotPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotPct")
plt.title("Top 10 Goal Scorers Shot Percentage 2021")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotspct2021.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2020_top10_goals['Player'],by_player_2020_top10_goals['ShotPct'])
plt.axhline(by_player_2020_avg['ShotPct'],color='red')
plt.axhline(by_player_2020_75['ShotPct'],color='orange')
plt.axhline(by_player_2020_25['ShotPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotPct")
plt.title("Top 10 Goal Scorers Shot Percentage 2020")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotspct2020.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2019_top10_goals['Player'],by_player_2019_top10_goals['ShotPct'])
plt.axhline(by_player_2019_avg['ShotPct'],color='red')
plt.axhline(by_player_2019_75['ShotPct'],color='orange')
plt.axhline(by_player_2019_25['ShotPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotPct")
plt.title("Top 10 Goal Scorers Shot Percentage 2019")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotspct2019.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2021_top10_goals['Player'],by_player_2021_top10_goals['ShotsOnGoal'])
plt.axhline(by_player_2021_avg['ShotsOnGoal'],color='red')
plt.axhline(by_player_2021_75['ShotsOnGoal'],color='orange')
plt.axhline(by_player_2021_25['ShotsOnGoal'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoal")
plt.title("Top 10 Goal Scorers Shots On Goal 2021")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoal2021.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2020_top10_goals['Player'],by_player_2020_top10_goals['ShotsOnGoal'])
plt.axhline(by_player_2020_avg['ShotsOnGoal'],color='red')
plt.axhline(by_player_2020_75['ShotsOnGoal'],color='orange')
plt.axhline(by_player_2020_25['ShotsOnGoal'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoal")
plt.title("Top 10 Goal Scorers Shots On Goal 2020")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoal2020.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2019_top10_goals['Player'],by_player_2019_top10_goals['ShotsOnGoal'])
plt.axhline(by_player_2019_avg['ShotsOnGoal'],color='red')
plt.axhline(by_player_2019_75['ShotsOnGoal'],color='orange')
plt.axhline(by_player_2019_25['ShotsOnGoal'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoal")
plt.title("Top 10 Goal Scorers Shots On Goal 2019")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoal2019.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2021_top10_goals['Player'],by_player_2021_top10_goals['ShotsOnGoalPct'])
plt.axhline(by_player_2021_avg['ShotsOnGoalPct'],color='red')
plt.axhline(by_player_2021_75['ShotsOnGoalPct'],color='orange')
plt.axhline(by_player_2021_25['ShotsOnGoalPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoalPct")
plt.title("Top 10 Goal Scorers Shots On Goal Percentage 2021")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoalpct2021.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2020_top10_goals['Player'],by_player_2020_top10_goals['ShotsOnGoalPct'])
plt.axhline(by_player_2020_avg['ShotsOnGoalPct'],color='red')
plt.axhline(by_player_2020_75['ShotsOnGoalPct'],color='orange')
plt.axhline(by_player_2020_25['ShotsOnGoalPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoalPct")
plt.title("Top 10 Goal Scorers Shots On Goal Percentage 2020")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoalpct2020.png')

# %%
fig = plt.figure(figsize = (5, 6))
 
plt.bar(by_player_2019_top10_goals['Player'],by_player_2019_top10_goals['ShotsOnGoalPct'])
plt.axhline(by_player_2019_avg['ShotsOnGoalPct'],color='red')
plt.axhline(by_player_2019_75['ShotsOnGoalPct'],color='orange')
plt.axhline(by_player_2019_25['ShotsOnGoalPct'],color='green')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel("Players")
plt.ylabel("ShotsOnGoalPct")
plt.title("Top 10 Goal Scorers Shots On Goal Percentage 2019")
plt.legend(['Average','75 Percentile','25 Percentile'])
#plt.show()
plt.savefig('img/top10_shotsonggoalpct2019.png')

# %%
df_2021_attack = df_2021[df_2021['position'].isin(['A'])]
#df_2021_attack
by_player_2021_attack = df_2021_attack.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2021_attack
df_2021_midfield = df_2021[df_2021['position'].isin(['M'])]
#df_2021_midfield
by_player_2021_midfield = df_2021_midfield.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2021_midfield
by_player_2021_attack_avg = by_player_2021_attack[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2021_attack_avg
by_player_2021_midfield_avg = by_player_2021_midfield[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2021_midfield_avg

df_2020_attack = df_2020[df_2020['position'].isin(['A'])]
#df_2020_attack
by_player_2020_attack = df_2020_attack.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2020_attack
df_2020_midfield = df_2020[df_2020['position'].isin(['M'])]
#df_2020_midfield
by_player_2020_midfield = df_2020_midfield.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2020_midfield
by_player_2020_attack_avg = by_player_2020_attack[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2020_attack_avg
by_player_2020_midfield_avg = by_player_2020_midfield[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2020_midfield_avg

df_2019_attack = df_2019[df_2019['position'].isin(['A'])]
#df_2019_attack
by_player_2019_attack = df_2019_attack.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2019_attack
df_2019_midfield = df_2019[df_2019['position'].isin(['M'])]
#df_2019_midfield
by_player_2019_midfield = df_2019_midfield.groupby('Player',as_index=False).agg({'Goals':'sum','Shots':'sum','ShotPct':'mean','ShotsOnGoal':'sum','ShotsOnGoalPct':'mean'})
#by_player_2019_midfield
by_player_2019_attack_avg = by_player_2019_attack[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2019_attack_avg
by_player_2019_midfield_avg = by_player_2019_midfield[['Goals','Shots','ShotPct','ShotsOnGoal','ShotsOnGoalPct']].mean()
#by_player_2019_midfield_avg

# %%
import numpy as np

labels = ['Goals', 'Shots','ShotsOnGoal']
attack_num = by_player_2021_attack_avg[['Goals','Shots','ShotsOnGoal']]
midfield_num = by_player_2021_midfield_avg[['Goals','Shots','ShotsOnGoal']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_num, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_num, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('#')
ax.set_title(' Goals and Shots Stats Attack vs Midfield 2021')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_num2021.png')

# %%
import numpy as np

labels = ['ShotPct', 'ShotsOnGoalPct']
attack_per = by_player_2021_attack_avg[['ShotPct', 'ShotsOnGoalPct']]
midfield_per = by_player_2021_midfield_avg[['ShotPct', 'ShotsOnGoalPct']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_per, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_per, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('%')
ax.set_title('Percentage Stats Attack vs Midfield 2021')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_per2021.png')

# %%
import numpy as np

labels = ['Goals', 'Shots','ShotsOnGoal']
attack_num = by_player_2020_attack_avg[['Goals','Shots','ShotsOnGoal']]
midfield_num = by_player_2020_midfield_avg[['Goals','Shots','ShotsOnGoal']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_num, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_num, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('#')
ax.set_title('Goal and Shot Stats Attack vs Midfield 2020')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_num2020.png')

# %%
import numpy as np

labels = ['ShotPct', 'ShotsOnGoalPct']
attack_per = by_player_2020_attack_avg[['ShotPct', 'ShotsOnGoalPct']]
midfield_per = by_player_2020_midfield_avg[['ShotPct', 'ShotsOnGoalPct']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_per, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_per, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('%')
ax.set_title('Percentage Stats Attack vs Midfield 2020')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_per2020.png')

# %%
import numpy as np

labels = ['Goals', 'Shots','ShotsOnGoal']
attack_num = by_player_2019_attack_avg[['Goals','Shots','ShotsOnGoal']]
midfield_num = by_player_2019_midfield_avg[['Goals','Shots','ShotsOnGoal']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_num, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_num, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('#')
ax.set_title('Goal and Shot Stats Attack vs Midfield 2019')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_num2019.png')

# %%
import numpy as np

labels = ['ShotPct', 'ShotsOnGoalPct']
attack_per = by_player_2019_attack_avg[['ShotPct', 'ShotsOnGoalPct']]
midfield_per = by_player_2019_midfield_avg[['ShotPct', 'ShotsOnGoalPct']]
x = np.arange(len(labels))# the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, attack_per, width, label='Attack')
rects2 = ax.bar(x + width/2, midfield_per, width, label='Midfield')
# Add some text for labels, title and custom x-axis tick labels, etc.       
ax.set_ylabel('%')
ax.set_title('Percentage Stats Attack vs Midfield 2019')
ax.set_xticks(x, labels)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
fig.tight_layout()
#plt.show()
plt.savefig('img/a_v_m_per2019.png')
